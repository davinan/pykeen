# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import getpass
import os
import sys
import time

sys.path.append("../src")
import matplotlib.pyplot as plt
import pandas as pd
import pykeen
import torch
from pykeen.pipeline import pipeline
from pykeen.datasets import get_dataset
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# ds = get_dataset(dataset="FB15k237")
ds = get_dataset(dataset="Nations")
ds.num_entities, ds.num_relations
training, testing, validation = ds.training, ds.testing, ds.validation
len(training.mapped_triples)
# all_triples = torch.cat((training.mapped_triples, testing.mapped_triples, validation.mapped_triples))
# Out:
# 1592

# %%
import pandas as pd
def test_model(dataset="Nations", model="TransE"):
    # with perturbation
    result_perturb = pipeline(
        dataset=dataset,
        model=model,
        random_seed=1235,
        device='cpu',
        training_kwargs=dict(num_epochs=100),  # Shouldn't take more than a minute or two on a nice computer
        negative_sampler="basic",
        use_perturbation=True, ###
        perturbator = "random",
    )

    #without perturbation
    result_normal = pipeline(
        dataset=dataset,
        model=model,
        random_seed=1235,
        device='cpu',
        training_kwargs=dict(num_epochs=100),  # Shouldn't take more than a minute or two on a nice computer
        negative_sampler="basic",
        use_perturbation=False, ###
        perturbator = "random",
    )
    
    all_df = result_normal.metric_results.to_df().drop(columns=["Value"])
    all_df["Normal"] = result_normal.metric_results.to_df()["Value"].values
    all_df["Perturbed"] = result_perturb.metric_results.to_df()["Value"].values
    return all_df

# %%
# %%capture tqdmm
results_transe = test_model("Nations", "TransE")
results_rotate = test_model("Nations", "RotatE")
results_transd = test_model("Nations", "TransD")
results_conve = test_model("Nations", "ConvE")
results_complex = test_model("Nations", "ComplEx")
print("Done!")

# %%
# results_complex
# Out:
#     Side   Type                Metric    Normal  Perturbed
# 0   head    avg    adjusted_mean_rank  0.987182   1.000077
# 1   tail    avg    adjusted_mean_rank  0.857059   0.821176
# 2   both    avg    adjusted_mean_rank  0.922121   0.910626
# 3   head    avg             mean_rank  4.557214   4.562189
# 4   head    avg  mean_reciprocal_rank  0.301029   0.294364
# 5   head    avg             hits_at_1  0.004975   0.000000
# 6   head    avg             hits_at_3  0.497512   0.477612
# 7   head    avg             hits_at_5  0.706468   0.696517
# 8   head    avg            hits_at_10  0.955224   0.950249
# 9   head   best             mean_rank  4.557214   4.562189
# 10  head   best  mean_reciprocal_rank  0.301029   0.294364
# 11  head   best             hits_at_1  0.004975   0.000000
# 12  head   best             hits_at_3  0.497512   0.477612
# 13  head   best             hits_at_5  0.706468   0.696517
# 14  head   best            hits_at_10  0.955224   0.950249
# 15  head  worst             mean_rank  4.557214   4.562189
# 16  head  worst  mean_reciprocal_rank  0.301029   0.294364
# 17  head  worst             hits_at_1  0.004975   0.000000
# 18  head  worst             hits_at_3  0.497512   0.477612
# 19  head  worst             hits_at_5  0.706468   0.696517
# 20  head  worst            hits_at_10  0.955224   0.950249
# 21  tail    avg             mean_rank  3.945274   3.766169
# 22  tail    avg  mean_reciprocal_rank  0.327227   0.337933
# 23  tail    avg             hits_at_1  0.004975   0.000000
# 24  tail    avg             hits_at_3  0.557214   0.577114
# 25  tail    avg             hits_at_5  0.796020   0.800995
# 26  tail    avg            hits_at_10  0.980100   0.990050
# 27  tail   best             mean_rank  3.945274   3.766169
# 28  tail   best  mean_reciprocal_rank  0.327227   0.337933
# 29  tail   best             hits_at_1  0.004975   0.000000
# 30  tail   best             hits_at_3  0.557214   0.577114
# 31  tail   best             hits_at_5  0.796020   0.800995
# 32  tail   best            hits_at_10  0.980100   0.990050
# 33  tail  worst             mean_rank  3.945274   3.766169
# 34  tail  worst  mean_reciprocal_rank  0.327227   0.337933
# 35  tail  worst             hits_at_1  0.004975   0.000000
# 36  tail  worst             hits_at_3  0.557214   0.577114
# 37  tail  worst             hits_at_5  0.796020   0.800995
# 38  tail  worst            hits_at_10  0.980100   0.990050
# 39  both    avg             mean_rank  4.251244   4.164179
# 40  both    avg  mean_reciprocal_rank  0.314128   0.316149
# 41  both    avg             hits_at_1  0.004975   0.000000
# 42  both    avg             hits_at_3  0.527363   0.527363
# 43  both    avg             hits_at_5  0.751244   0.748756
# 44  both    avg            hits_at_10  0.967662   0.970149
# 45  both   best             mean_rank  4.251244   4.164179
# 46  both   best  mean_reciprocal_rank  0.314128   0.316149
# 47  both   best             hits_at_1  0.004975   0.000000
# 48  both   best             hits_at_3  0.527363   0.527363
# 49  both   best             hits_at_5  0.751244   0.748756
# 50  both   best            hits_at_10  0.967662   0.970149
# 51  both  worst             mean_rank  4.251244   4.164179
# 52  both  worst  mean_reciprocal_rank  0.314128   0.316149
# 53  both  worst             hits_at_1  0.004975   0.000000
# 54  both  worst             hits_at_3  0.527363   0.527363
# 55  both  worst             hits_at_5  0.751244   0.748756
# 56  both  worst            hits_at_10  0.967662   0.970149

# %%
def display_all(results: list, models: list):
    metrics = results[0].drop(columns=["Normal", "Perturbed"])
    for r, name in zip(results, models):
        metrics[f"{name}_normal"] = r["Normal"].values
        metrics[f"{name}_perturbed"] = r["Perturbed"].values
        metrics[f"{name}_diff"] = r["Normal"].values - r["Perturbed"].values
    return metrics
results = [
    results_transe,
    results_rotate,
    results_transd,
    results_conve,
    results_complex,
]
names = [
    "TransE",
    "RotatE",
    "TransD",
    "ConvE",
    "ComplEx",
]

all_results = display_all(results, names)

# %%
all_results
# Out:
#     Side   Type                Metric  TransE_normal  TransE_perturbed  \
# 0   tail    avg    adjusted_mean_rank       0.857059          0.821176
# 1   head    avg    adjusted_mean_rank       0.987182          1.000077
# 2   both    avg    adjusted_mean_rank       0.922121          0.910626
# 3   tail  worst             mean_rank       3.945274          3.766169
# 4   tail  worst  mean_reciprocal_rank       0.327227          0.337933
# 5   tail  worst             hits_at_1       0.004975          0.000000
# 6   tail  worst             hits_at_3       0.557214          0.577114
# 7   tail  worst             hits_at_5       0.796020          0.800995
# 8   tail  worst            hits_at_10       0.980100          0.990050
# 9   tail   best             mean_rank       3.945274          3.766169
# 10  tail   best  mean_reciprocal_rank       0.327227          0.337933
# 11  tail   best             hits_at_1       0.004975          0.000000
# 12  tail   best             hits_at_3       0.557214          0.577114
# 13  tail   best             hits_at_5       0.796020          0.800995
# 14  tail   best            hits_at_10       0.980100          0.990050
# 15  tail    avg             mean_rank       3.945274          3.766169
# 16  tail    avg  mean_reciprocal_rank       0.327227          0.337933
# 17  tail    avg             hits_at_1       0.004975          0.000000
# 18  tail    avg             hits_at_3       0.557214          0.577114
# 19  tail    avg             hits_at_5       0.796020          0.800995
# 20  tail    avg            hits_at_10       0.980100          0.990050
# 21  head  worst             mean_rank       4.557214          4.562189
# 22  head  worst  mean_reciprocal_rank       0.301029          0.294364
# 23  head  worst             hits_at_1       0.004975          0.000000
# 24  head  worst             hits_at_3       0.497512          0.477612
# 25  head  worst             hits_at_5       0.706468          0.696517
# 26  head  worst            hits_at_10       0.955224          0.950249
# 27  head   best             mean_rank       4.557214          4.562189
# 28  head   best  mean_reciprocal_rank       0.301029          0.294364
# 29  head   best             hits_at_1       0.004975          0.000000
# 30  head   best             hits_at_3       0.497512          0.477612
# 31  head   best             hits_at_5       0.706468          0.696517
# 32  head   best            hits_at_10       0.955224          0.950249
# 33  head    avg             mean_rank       4.557214          4.562189
# 34  head    avg  mean_reciprocal_rank       0.301029          0.294364
# 35  head    avg             hits_at_1       0.004975          0.000000
# 36  head    avg             hits_at_3       0.497512          0.477612
# 37  head    avg             hits_at_5       0.706468          0.696517
# 38  head    avg            hits_at_10       0.955224          0.950249
# 39  both  worst             mean_rank       4.251244          4.164179
# 40  both  worst  mean_reciprocal_rank       0.314128          0.316149
# 41  both  worst             hits_at_1       0.004975          0.000000
# 42  both  worst             hits_at_3       0.527363          0.527363
# 43  both  worst             hits_at_5       0.751244          0.748756
# 44  both  worst            hits_at_10       0.967662          0.970149
# 45  both   best             mean_rank       4.251244          4.164179
# 46  both   best  mean_reciprocal_rank       0.314128          0.316149
# 47  both   best             hits_at_1       0.004975          0.000000
# 48  both   best             hits_at_3       0.527363          0.527363
# 49  both   best             hits_at_5       0.751244          0.748756
# 50  both   best            hits_at_10       0.967662          0.970149
# 51  both    avg             mean_rank       4.251244          4.164179
# 52  both    avg  mean_reciprocal_rank       0.314128          0.316149
# 53  both    avg             hits_at_1       0.004975          0.000000
# 54  both    avg             hits_at_3       0.527363          0.527363
# 55  both    avg             hits_at_5       0.751244          0.748756
# 56  both    avg            hits_at_10       0.967662          0.970149
#
#     TransE_diff  RotatE_normal  RotatE_perturbed  RotatE_diff  TransD_normal  \
# 0      0.035884       0.744914          0.718223     0.026691       0.818620
# 1     -0.012895       0.961463          0.958712     0.002751       0.964128
# 2      0.011495       0.853189          0.838468     0.014721       0.891374
# 3      0.179104       3.537313          3.407960     0.129353       3.791045
# 4     -0.010707       0.497110          0.516760    -0.019650       0.344585
# 5      0.004975       0.288557          0.318408    -0.029851       0.029851
# 6     -0.019900       0.636816          0.616915     0.019900       0.547264
